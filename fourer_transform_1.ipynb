# %%
import matplotlib.pyplot as plt
import numpy as np
from src import plot_non_periodic_ex1, plot_non_periodic_ft_ex1, plot_non_periodic_invft_ex1

# %% [markdown]
# ## フーリエ変換
# 次の関数を考える．
# $$
# \begin{align*}
# &f(t) =
# \begin{cases}
# 1\qquad \textrm{if}\ 0 \leq t \leq 1
# \\
# 0\qquad \textrm{other}
# \end{cases}
# \end{align*}
# $$

# %%
fig, ax = plt.subplots(figsize=(13, 3))
plot_non_periodic_ex1(ax, t = np.linspace(-2, 6, 1000))
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Step1: フーリエ変換を行い，関数$f(t)$を波数空間における関数$F(k)$に変換する．
# $$
# \begin{align*}
# F(k) &= \frac{1}{\sqrt{2\pi}} \int^\infty_{-\infty} f(t) \exp [-ik t]dt
# \\\\
# &=\frac{1-e^{-ik}}{\sqrt{2\pi}i k}
# \end{align*}
# $$

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
plot_non_periodic_ex1(ax[0], t=np.linspace(-2, 6, 1000))
plot_non_periodic_ft_ex1(ax[1], t=np.linspace(-15, 15, 1000))
plt.tight_layout()
plt.show()
# Out:
# /home/asaka/Pros/teachings/fourier/venv/lib/python3.12/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/asaka/Pros/teachings/fourier/venv/lib/python3.12/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# フーリエ変換後の関数$F(k)$: 重ね合わせる波動の振幅と考えて良い．

# %% [markdown]
# #### Step2: フーリエ逆変換によって元の関数$f(t)$を再現してみる．
# $$
# \begin{align*}
# f(t) &= \frac{1}{\sqrt{2\pi}} \int^\infty_{-\infty} F(k) \exp [ik t]dk
# \end{align*}
# $$
# 積分範囲を$k\in[-\infty, \infty]$から$k\in[-N,N]$に打ち切って計算を行ってみる．
# $$
# \begin{align*}
# f(t) \approx \frac{1}{\sqrt{2\pi}} \int^N_{-N} F(k) \exp [ik t]dk
# \end{align*}
# $$
# このとき，$N$をどの程度まで大きくすれば次のように定義されていた元の関数$f(t)$を再現できるかを調べてみよう．
# $$
# \begin{align*}
# &f(t) =
# \begin{cases}
# 1\qquad \textrm{if}\ 0 \leq t \leq 1
# \\
# 0\qquad \textrm{other}
# \end{cases}
# \end{align*}
# $$

# %%
N = 1
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
D = 2 * N if N > 100 else 100
plot_non_periodic_ft_ex1(ax[0], t=np.linspace(-1 * D, D, 1000), range_color_red=(-N, N))
plot_non_periodic_invft_ex1(ax[1], N, t=np.linspace(-1, 4, 1000))
plt.tight_layout()
plt.show()

# %%
N = 2
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
D = 2 * N if N > 100 else 100
plot_non_periodic_ft_ex1(ax[0], t=np.linspace(-1 * D, D, 1000), range_color_red=(-N, N))
plot_non_periodic_invft_ex1(ax[1], N, t=np.linspace(-1, 4, 1000))
plt.tight_layout()
plt.show()

# %%
N = 5
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
D = 2 * N if N > 100 else 100
plot_non_periodic_ft_ex1(ax[0], t=np.linspace(-1 * D, D, 1000), range_color_red=(-N, N))
plot_non_periodic_invft_ex1(ax[1], N, t=np.linspace(-1, 4, 1000))
plt.tight_layout()
plt.show()

# %%
N = 9
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
D = 2 * N if N > 100 else 100
plot_non_periodic_ft_ex1(ax[0], t=np.linspace(-1 * D, D, 1000), range_color_red=(-N, N))
plot_non_periodic_invft_ex1(ax[1], N, t=np.linspace(-1, 4, 1000))
plt.tight_layout()
plt.show()

# %%
N = 100
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
D = 2 * N if N > 100 else 100
plot_non_periodic_ft_ex1(ax[0], t=np.linspace(-1 * D, D, 1000), range_color_red=(-N, N))
plot_non_periodic_invft_ex1(ax[1], N, t=np.linspace(-1, 4, 1000))
plt.tight_layout()
plt.show()

# %%
N = 1000
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
D = 2 * N if N > 100 else 100
plot_non_periodic_ft_ex1(ax[0], t=np.linspace(-1 * D, D, 1000), range_color_red=(-N, N))
plot_non_periodic_invft_ex1(ax[1], N, t=np.linspace(-1, 4, 1000))
plt.tight_layout()
plt.show()

# %%
N = 10000
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
D = 2 * N if N > 100 else 100
plot_non_periodic_ft_ex1(ax[0], t=np.linspace(-1 * D, D, 1000), range_color_red=(-N, N))
plot_non_periodic_invft_ex1(ax[1], N, t=np.linspace(-1, 4, 1000))
plt.tight_layout()
plt.show()
