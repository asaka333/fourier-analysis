# %%
import matplotlib.pyplot as plt
from src import plot_periodic_ex1, plot_Cn_ex1, plot_periodic_reconst_ex1

# %% [markdown]
# ## フーリエ級数展開
# 以下の周期関数を三角関数の無限級数の形式を考える．
# $$
# \begin{align*}
# &f(t) =
# \begin{cases}
# 0\qquad \textrm{if}\ -1 \leq t <0
# \\
# 1\qquad \textrm{if}\ 0 \leq t <1
# \end{cases}
# \\
# &f(t+2) = f(t)
# \end{align*}
# $$

# %%
fig, ax = plt.subplots(figsize=(13, 3))
plot_periodic_ex1(ax)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Step1: フーリエ係数を計算する
# $$
# \begin{align*}
# C_n &= \frac{1}{2L} \int^L_{-L} f(t) \exp \left[-i \frac{n\pi}{L}t\right] dt
# \\\\
# &=
# \begin{cases}
# \displaystyle
# \frac{1}{2} \quad \textrm{if}\quad n= 1
# \\\\
# \displaystyle
# \frac{i}{2n\pi} \left((-1)^n - 1 \right) \quad \textrm{if}\quad n\neq 1
# \end{cases}
# \end{align*}
# $$

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
plot_periodic_ex1(ax[0])
plot_Cn_ex1(ax[1])
plt.tight_layout()
plt.show()

# %% [markdown]
# 係数：重ね合わせる波動の振幅と考えて良い．

# %% [markdown]
# #### Step2: フーリエ級数展開を計算する
# $$
# \begin{align*}
# f(t) &= \sum^\infty_{n=-\infty} C_n \exp \left[in\pi t \right]
# \qquad \left( = \frac{1}{2} + \sum^{\infty}_{k=1} \frac{2}{(2k+1)\pi} \sin \left[(2k+1)\pi t \right]\right)
# \end{align*}
# $$
# 実際にはコンピューターは$\infty$を扱えないので，$n\leq |N|$で総和を打ち切ってフーリエ級数展開を計算する：
# $$
# \begin{align*}
# f(t) &= \sum^N_{n=-N} C_n \exp \left[in\pi t \right]
# \end{align*}
# $$

# %%
N = 1
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
plot_Cn_ex1(ax[0], N, N)
plot_periodic_reconst_ex1(ax[1], N)
plt.tight_layout()
plt.show()

# %%
N = 2
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
plot_Cn_ex1(ax[0], N, N)
plot_periodic_reconst_ex1(ax[1], N)
plt.tight_layout()
plt.show()

# %%
N = 4
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
plot_Cn_ex1(ax[0], N, N)
plot_periodic_reconst_ex1(ax[1], N)
plt.tight_layout()
plt.show()

# %%
N = 10
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
plot_Cn_ex1(ax[0], N, N)
plot_periodic_reconst_ex1(ax[1], N)
plt.tight_layout()
plt.show()

# %%
N = 100
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
plot_Cn_ex1(ax[0], N, N)
plot_periodic_reconst_ex1(ax[1], N)
plt.tight_layout()
plt.show()

# %%
N = 2000
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
plot_Cn_ex1(ax[0], N, N)
plot_periodic_reconst_ex1(ax[1], N)
plt.tight_layout()
plt.show()
